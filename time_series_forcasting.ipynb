# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# %%
date_rng = pd.date_range(start= "2023-01-02", end ="2023-12-31", freq ="D" )

# %%
date_rng
# Out:
# DatetimeIndex(['2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05',
#                '2023-01-06', '2023-01-07', '2023-01-08', '2023-01-09',
#                '2023-01-10', '2023-01-11',
#                ...
#                '2023-12-22', '2023-12-23', '2023-12-24', '2023-12-25',
#                '2023-12-26', '2023-12-27', '2023-12-28', '2023-12-29',
#                '2023-12-30', '2023-12-31'],
#               dtype='datetime64[ns]', length=364, freq='D')

# %%
time_series_data = pd.Series(np.random.randn(len(date_rng)), index = date_rng)

# %%
time_series_data
# Out:
# 2023-01-02   -0.552624
# 2023-01-03   -0.540892
# 2023-01-04   -1.792030
# 2023-01-05   -1.451075
# 2023-01-06    0.121677
#                 ...
# 2023-12-27    0.830801
# 2023-12-28    0.733489
# 2023-12-29   -2.011822
# 2023-12-30    1.774279
# 2023-12-31    0.432625
# Freq: D, Length: 364, dtype: float64

# %%
plt.plot(time_series_data)
plt.title("ARIMA data")
plt.show()

# %%
model = ARIMA(time_series_data, order = (1,1,1))

# %%
(2,1,3)
# Out:
# (2, 1, 3)

# %%
fit_model = model.fit()

# %%
forecast_steps = 30
forecast = fit_model.forecast(steps = forecast_steps)

# %%
plt.plot(time_series_data, label = "Original Data")
plt.plot(forecast, label = "Forecast")
plt.legend()
plt.title("ARIMA forecasts")
plt.show()
